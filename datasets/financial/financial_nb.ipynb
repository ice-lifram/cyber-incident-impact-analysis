# %% [markdown]
# # **Financial Impact Analysis**

# %%
import pandas as pd

df = pd.read_csv('financial_impact.csv')

# %% [markdown]
# **Variables**

# %%
direct_losses = df['direct_loss_usd']
direct_loss_method = df['direct_loss_method']
recovery_cost = df['recovery_cost_usd']
total_loss = df['total_loss_usd']
insurance_payout = df['insurance_payout_usd']
regulatory_fine = df['regulatory_fine_usd']
total_loss_method = df['total_loss_method']
ransom_demanded = df['ransom_demanded_usd']
ransom_paid = df['ransom_paid_usd']
ransom_source = df['ransom_source']

# %% [markdown]
# **Analysis**

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 778 entries, 0 to 777
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   incident_id             778 non-null    str
#  1   direct_loss_usd         778 non-null    float64
#  2   direct_loss_method      778 non-null    str
#  3   ransom_demanded_usd     206 non-null    float64
#  4   ransom_paid_usd         86 non-null     float64
#  5   ransom_source           86 non-null     str
#  6   recovery_cost_usd       778 non-null    float64
#  7   legal_fees_usd          778 non-null    float64
#  8   regulatory_fine_usd     132 non-null    float64
#  9   insurance_payout_usd    435 non-null    float64
#  10  total_loss_usd          778 non-null    float64
#  11  total_loss_method       778 non-null    str
#  12  total_loss_lower_bound  778 non-null    float64
#  13  total_loss_upper_bound  778 non-null    float64
#  14  inflation_adjusted_usd  778 non-null    float64
#  15  cpi_index_used          778 non-null    str
#  16  notes                   248 non-null    str
#  17  created_at              778 non-null    str
#  18  updated_at              778 non-null    str
# dtypes: float64(11), str(8)
# memory usage: 115.6 KB
# None

# %%
# Direct Losses
print(direct_losses.describe())
print(direct_losses.value_counts())
# Out:
# Running cells with 'myenv (Python 3.14.5)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '/home/ice_lifram/Code/projects/indus-risk-analysis/myenv/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
# Recovery Costs
print(recovery_cost.describe())
# Out:
# count    7.780000e+02
# mean     2.618556e+07
# std      7.816093e+07
# min      5.703142e+04
# 25%      2.055169e+06
# 50%      6.129803e+06
# 75%      1.840980e+07
# max      1.238193e+09
# Name: recovery_cost_usd, dtype: float64

# %%
# Total Loss
print(total_loss.describe())
# Out:
# count    7.780000e+02
# mean     7.099600e+07
# std      2.151881e+08
# min      1.737931e+05
# 25%      6.166441e+06
# 50%      1.656491e+07
# 75%      5.259585e+07
# max      3.451548e+09
# Name: total_loss_usd, dtype: float64

# %%
# Insurance Payout
print(insurance_payout.describe())
# Out:
# count    4.350000e+02
# mean     2.665044e+07
# std      7.593903e+07
# min      6.280104e+04
# 25%      2.277000e+06
# 50%      6.316200e+06
# 75%      1.844803e+07
# max      1.054416e+09
# Name: insurance_payout_usd, dtype: float64

# %%
# Ransom Demanded
print(ransom_demanded.describe())
# Out:
# count    2.060000e+02
# mean     8.017672e+06
# std      1.580389e+07
# min      5.000000e+04
# 25%      6.578965e+05
# 50%      1.979266e+06
# 75%      6.303181e+06
# max      7.500000e+07
# Name: ransom_demanded_usd, dtype: float64

# %%
# Ransom Paid
print(ransom_paid.describe())
# Out:
# count    8.600000e+01
# mean     4.497464e+06
# std      9.186802e+06
# min      1.610098e+04
# 25%      4.247265e+05
# 50%      1.129759e+06
# 75%      3.589926e+06
# max      5.188418e+07
# Name: ransom_paid_usd, dtype: float64

# %%
# Ransom Source
print(ransom_source.value_counts())
# Out:
# ransom_source
# congressional testimony    19
# blockchain analysis        19
# FBI disclosure             15
# company statement          13
# insurance claim record     11
# court filing                9
# Name: count, dtype: int64

# %%
#
